# %% [markdown]
# # EEG Preprocessing
#
# **Purpose:** Run the preprocessing pipeline for the raw EEG recordings.
#
# **Input:** Raw BIDS EEG data from ds004033.
#
# **Output:** Cleaned EEG recordings after filtering (0.1–40 Hz), notch removal (50/100 Hz), bad channel detection and interpolation (RANSAC/PREP-style), average re-referencing, and ICA artifact removal (Picard/FastICA + ICLabel). The cleaned data are saved for downstream analyses.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[2]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from shared.src.preprocessing import PreprocessingConfig, run_preprocessing

# %%
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'preprocessing_authors.yaml'
config = PreprocessingConfig.from_yaml(CONFIG_PATH, project_root=PROJECT_ROOT)

manifest = run_preprocessing(config, max_runs=1)
manifest.head()
