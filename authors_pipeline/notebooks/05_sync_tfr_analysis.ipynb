# %% [markdown]
# # Walking Synchronization Time–Frequency Analysis
#
# **Purpose:** Compute time–frequency representations during the walking synchronization task.
#
# **Input:** Preprocessed EEG recordings with gait event markers.
#
# **Output:** Morlet wavelet power (3–35 Hz, 4–10 cycles) computed over stride cycles (RHS→RHS). Band power is extracted for alpha-mu (7.5–12.5 Hz at C4/C6/CP4/CP6) and beta (16–32 Hz at C1/Cz/C2) with baseline correction from −0.2 to 0 s.

# %%
from pathlib import Path
from shared.src.sync_tfr_analysis import SyncTFRConfig, run_sync_tfr_analysis
PROJECT_ROOT = Path.cwd()
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'sync_tfr_authors.yaml'
config = SyncTFRConfig.from_yaml(CONFIG_PATH, project_root=PROJECT_ROOT)
config

# %%
outputs = run_sync_tfr_analysis(config)
outputs['stride_manifest'].head(), outputs['run_level_bandpower'].head(), outputs['stats_results'].head()
