# %% [markdown]
# # Synchronization Analysis Comparison
#
# **Purpose:** Compare time–frequency results between the authors’ pipeline and our preprocessing pipeline.
#
# **Input:** Alpha-mu and beta band power extracted from stride-aligned EEG data.
#
# **Output:** Group-level comparisons across walking conditions with paired statistical tests and FDR correction to evaluate differences between preprocessing strategies.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'shared').exists():
    PROJECT_ROOT = Path.cwd().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from shared.src.sync_comparison import SyncComparisonConfig, run_sync_comparison
config_path = PROJECT_ROOT / 'configs/sync_comparison.yaml'
config = SyncComparisonConfig.from_yaml(config_path, project_root=PROJECT_ROOT)
outputs = run_sync_comparison(config)
summary = outputs['summary']
subject_compare = outputs['subject_bandpower_comparison']
stats_compare = outputs['stats_comparison']

# %%
summary

# %%
subject_compare.head(20)

# %%
stats_compare
