# %% [markdown]
# # EEG Preprocessing (Our Pipeline)
#
# **Purpose:** Apply our preprocessing pipeline to the raw EEG recordings.
#
# **Input:** Raw BIDS EEG data from ds004033.
#
# **Output:** Cleaned EEG recordings after band-pass filtering (0.1–40 Hz), notch removal (50/100 Hz), bad channel detection using PREP/RANSAC-style checks, interpolation of bad channels, average re-referencing, and ICA artifact removal (Picard/FastICA with ICLabel and EOG correlation). The cleaned data are saved for downstream analyses.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[2]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from shared.src.preprocessing import PreprocessingConfig, run_preprocessing

# %%
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'preprocessing_ours.yaml'
config = PreprocessingConfig.from_yaml(CONFIG_PATH, project_root=PROJECT_ROOT)

manifest = run_preprocessing(config, max_runs=1)
manifest.head()
