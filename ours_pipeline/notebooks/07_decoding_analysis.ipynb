# %% [markdown]
# # EEG Decoding Analysis (Our Pipeline)
#
# **Purpose:** Perform time-resolved decoding of walking conditions using EEG processed with our preprocessing pipeline.
#
# **Input:** Epochs from −0.2 to 0.8 s derived from the oddball task.
#
# **Output:** Classification performance (AUC) over time using a linear classifier with cross-validation across three condition pairs: standing vs walking alone, standing vs walking together, and walking alone vs walking together.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'shared').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from shared.src.decoding_analysis import DecodingConfig, run_decoding_analysis
config = DecodingConfig.from_yaml(PROJECT_ROOT / 'configs/decoding_ours.yaml', project_root=PROJECT_ROOT)
outputs = run_decoding_analysis(config)
outputs['summary']

# %%
outputs['stats_results'].head(20)

# %%
outputs['group_auc_summary'].head(20)
