# %% [markdown]
# # Event Mapping
#
# **Purpose:** Convert raw event codes from the dataset into meaningful experimental conditions used in the analysis.
#
# **Input:** Event annotations from the raw EEG recordings.
#
# **Output:** Mapping of event codes to experimental conditions (standing, walking alone, walking together; standard vs deviant stimuli) that will be used consistently across the analysis pipeline.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from shared.src.event_mapping import EventMappingConfig, build_event_mapping_table, write_event_mapping_outputs

config = EventMappingConfig.from_yaml(PROJECT_ROOT / 'configs' / 'event_mapping.yaml', project_root=PROJECT_ROOT)
outputs = build_event_mapping_table(config)
written = write_event_mapping_outputs(config, outputs)
written

# %% [markdown]
# ## Mapping table preview

# %%
outputs['mapping'].head(30)

# %% [markdown]
# ## Unresolved labels that still need inspection

# %%
outputs['unresolved'].head(50)

# %% [markdown]
# ## Authors repo hints recovered from MATLAB scripts

# %%
outputs['authors_strings'].head(50)

# %% [markdown]
# ## Canonical dictionaries to reuse later

# %%
outputs['oddball_condition_dict'].head(30), outputs['sync_gait_dict'].head(30)
