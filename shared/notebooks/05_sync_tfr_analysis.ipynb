# %% [markdown]
# # Walking Synchronization Time–Frequency Analysis
#
# **Purpose:** Analyze oscillatory brain activity during the walking synchronization task.
#
# **Input:** Preprocessed EEG recordings with gait event markers.
#
# **Output:** Stride-aligned time–frequency representations computed using Morlet wavelets (3–35 Hz). Band power is extracted for alpha-mu (7.5–12.5 Hz at C4/C6/CP4/CP6) and beta (16–32 Hz at C1/Cz/C2) with baseline correction applied before stride onset.

# %%
from pathlib import Path
from shared.src.sync_tfr_analysis import SyncTFRConfig, run_sync_tfr_analysis
PROJECT_ROOT = Path.cwd()
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'sync_tfr_ours.yaml'
config = SyncTFRConfig.from_yaml(CONFIG_PATH, project_root=PROJECT_ROOT)
config

# %%
outputs = run_sync_tfr_analysis(config)
outputs['stride_manifest'].head(), outputs['run_level_bandpower'].head(), outputs['stats_results'].head()
